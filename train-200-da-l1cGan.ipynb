# %% [markdown]
# # Training notebook

# %% [markdown]
# The goal of this notebook is to obtain pictures generated by the Pix2Pix model at different stages of training.

# %% [markdown]
# ### 0. Libraries and dataset

# %%
import utils
import model

# %%
# set dataset name
dataset_name = 'facades'

# %% [markdown]
# ## I. No transformation, batch size of 1

# %% [markdown]
# ### 1. Instantiate dataloaders

# %%
# instantiate datasets and dataloaders
datasets = {mode: utils.ImageDataset(dataset_name = dataset_name, transform=utils.data_transforms[mode], mode = mode) for mode in ['train', 'val']}
dataloaders = {'train': utils.DataLoader(datasets['train'], batch_size=1, shuffle=True),
                    'val': utils.DataLoader(datasets['val'], batch_size=1, shuffle=False)}

# %% [markdown]
# ### 2. Create model

# %%
# instantiate model
p2p = model.Pix2Pix().to(utils.device)

# %% [markdown]
# ### 3. Train

# %%
history = utils.train(model = p2p,
            n_epochs = 200,
            display_step = 20,
            save_step = 20,
            dataloaders = dataloaders,
            filename = 'facades_long_da',
            lr = 2e-4,
            lbd = 200,
            loss_l1_true = True,
            loss_l2_true = False,
            loss_cGAN_true = True)
# Out:
# Epoch 1/200
# ----------
# gen_loss: 41.5406, gan_loss: 2.4662, l1_loss: 0.1954, disc_loss: 0.2146.
#
#
# Epoch 2/200
# ----------
# gen_loss: 38.8495, gan_loss: 3.1295, l1_loss: 0.1786, disc_loss: 0.1307.
#
#
# Epoch 3/200
# ----------
# gen_loss: 39.9938, gan_loss: 3.0625, l1_loss: 0.1847, disc_loss: 0.1606.
#
#
# Epoch 4/200
# ----------
# gen_loss: 40.0749, gan_loss: 2.9766, l1_loss: 0.1855, disc_loss: 0.1732.
#
#
# Epoch 5/200
# ----------
# gen_loss: 39.7825, gan_loss: 2.8786, l1_loss: 0.1845, disc_loss: 0.1896.
#
#
# Epoch 6/200
# ----------
# gen_loss: 40.2373, gan_loss: 2.9748, l1_loss: 0.1863, disc_loss: 0.1779.
#
#
# Epoch 7/200
# ----------
# gen_loss: 40.3333, gan_loss: 2.6410, l1_loss: 0.1885, disc_loss: 0.2323.
#
#
# Epoch 8/200
# ----------
# gen_loss: 39.8733, gan_loss: 2.8942, l1_loss: 0.1849, disc_loss: 0.2068.
#
#
# Epoch 9/200
# ----------
# gen_loss: 39.9611, gan_loss: 2.7448, l1_loss: 0.1861, disc_loss: 0.2221.
#
#
# Epoch 10/200
# ----------
# gen_loss: 40.2019, gan_loss: 2.8027, l1_loss: 0.1870, disc_loss: 0.2164.
#
#
# Epoch 11/200
# ----------
# gen_loss: 39.7129, gan_loss: 2.5853, l1_loss: 0.1856, disc_loss: 0.2335.
#
#
# Epoch 12/200
# ----------
# gen_loss: 39.7694, gan_loss: 2.6461, l1_loss: 0.1856, disc_loss: 0.2284.
#
#
# Epoch 13/200
# ----------
# gen_loss: 40.0723, gan_loss: 2.5782, l1_loss: 0.1875, disc_loss: 0.2366.
#
#
# Epoch 14/200
# ----------
# gen_loss: 40.0431, gan_loss: 2.5667, l1_loss: 0.1874, disc_loss: 0.2314.
#
#
# Epoch 15/200
# ----------
# gen_loss: 39.7622, gan_loss: 2.5919, l1_loss: 0.1859, disc_loss: 0.2587.
#
#
# Epoch 16/200
# ----------
# gen_loss: 39.8105, gan_loss: 2.5412, l1_loss: 0.1863, disc_loss: 0.2559.
#
#
# Epoch 17/200
# ----------
# gen_loss: 39.2541, gan_loss: 2.4774, l1_loss: 0.1839, disc_loss: 0.2541.
#
#
# Epoch 18/200
# ----------
# gen_loss: 39.0688, gan_loss: 2.4861, l1_loss: 0.1829, disc_loss: 0.2484.
#
#
# Epoch 19/200
# ----------
# gen_loss: 39.2561, gan_loss: 2.4075, l1_loss: 0.1842, disc_loss: 0.2689.
#
#
# Epoch 20/200
# ----------
# gen_loss: 39.2327, gan_loss: 2.4631, l1_loss: 0.1838, disc_loss: 0.2588.
# saving model weights ...
#
#
# Epoch 21/200
# ----------
# gen_loss: 39.1276, gan_loss: 2.5274, l1_loss: 0.1830, disc_loss: 0.2491.
#
#
# Epoch 22/200
# ----------
# gen_loss: 39.2342, gan_loss: 2.4741, l1_loss: 0.1838, disc_loss: 0.2473.
#
#
# Epoch 23/200
# ----------
# gen_loss: 39.0405, gan_loss: 2.5740, l1_loss: 0.1823, disc_loss: 0.2594.
#
#
# Epoch 24/200
# ----------
# gen_loss: 38.9646, gan_loss: 2.5830, l1_loss: 0.1819, disc_loss: 0.2439.
#
#
# Epoch 25/200
# ----------
# gen_loss: 39.0335, gan_loss: 2.5951, l1_loss: 0.1822, disc_loss: 0.2402.
#
#
# Epoch 26/200
# ----------
# gen_loss: 38.6207, gan_loss: 2.5824, l1_loss: 0.1802, disc_loss: 0.2487.
#
#
# Epoch 27/200
# ----------
# gen_loss: 38.5873, gan_loss: 2.5419, l1_loss: 0.1802, disc_loss: 0.2639.
#
#
# Epoch 28/200
# ----------
# gen_loss: 38.7745, gan_loss: 2.6020, l1_loss: 0.1809, disc_loss: 0.2230.
#
#
# Epoch 29/200
# ----------
# gen_loss: 38.4672, gan_loss: 2.6404, l1_loss: 0.1791, disc_loss: 0.2663.
#
#
# Epoch 30/200
# ----------
# gen_loss: 38.3495, gan_loss: 2.6055, l1_loss: 0.1787, disc_loss: 0.2375.
#
#
# Epoch 31/200
# ----------
# gen_loss: 38.4400, gan_loss: 2.5322, l1_loss: 0.1795, disc_loss: 0.2620.
#
#
# Epoch 32/200
# ----------
# gen_loss: 37.8556, gan_loss: 2.5595, l1_loss: 0.1765, disc_loss: 0.2428.
#
#
# Epoch 33/200
# ----------
# gen_loss: 38.0802, gan_loss: 2.5382, l1_loss: 0.1777, disc_loss: 0.2368.
#
#
# Epoch 34/200
# ----------
# gen_loss: 37.9155, gan_loss: 2.5957, l1_loss: 0.1766, disc_loss: 0.2377.
#
#
# Epoch 35/200
# ----------
# gen_loss: 37.7486, gan_loss: 2.5390, l1_loss: 0.1760, disc_loss: 0.2645.
#
#
# Epoch 36/200
# ----------
# gen_loss: 37.8121, gan_loss: 2.4870, l1_loss: 0.1766, disc_loss: 0.2593.
#
#
# Epoch 37/200
# ----------
# gen_loss: 37.6139, gan_loss: 2.5319, l1_loss: 0.1754, disc_loss: 0.2589.
#
#
# Epoch 38/200
# ----------
# gen_loss: 37.2273, gan_loss: 2.5138, l1_loss: 0.1736, disc_loss: 0.2679.
#
#
# Epoch 39/200
# ----------
# gen_loss: 37.5508, gan_loss: 2.5278, l1_loss: 0.1751, disc_loss: 0.2510.
#
#
# Epoch 40/200
# ----------
# gen_loss: 36.8884, gan_loss: 2.5887, l1_loss: 0.1715, disc_loss: 0.2512.
# saving model weights ...
#
#
# Epoch 41/200
# ----------
# gen_loss: 36.8617, gan_loss: 2.5192, l1_loss: 0.1717, disc_loss: 0.2562.
#
#
# Epoch 42/200
# ----------
# gen_loss: 36.6787, gan_loss: 2.5364, l1_loss: 0.1707, disc_loss: 0.2568.
#
#
# Epoch 43/200
# ----------
# gen_loss: 36.6347, gan_loss: 2.4719, l1_loss: 0.1708, disc_loss: 0.2523.
#
#
# Epoch 44/200
# ----------
# gen_loss: 36.6512, gan_loss: 2.4939, l1_loss: 0.1708, disc_loss: 0.2681.
#
#
# Epoch 45/200
# ----------
# gen_loss: 36.7365, gan_loss: 2.4903, l1_loss: 0.1712, disc_loss: 0.2599.
#
#
# Epoch 46/200
# ----------
# gen_loss: 36.4675, gan_loss: 2.5438, l1_loss: 0.1696, disc_loss: 0.2548.
#
#
# Epoch 47/200
# ----------
# gen_loss: 36.3335, gan_loss: 2.5579, l1_loss: 0.1689, disc_loss: 0.2514.
#
#
# Epoch 48/200
# ----------
# gen_loss: 36.3848, gan_loss: 2.5355, l1_loss: 0.1692, disc_loss: 0.2513.
#
#
# Epoch 49/200
# ----------
# gen_loss: 35.9641, gan_loss: 2.5431, l1_loss: 0.1671, disc_loss: 0.2617.
#
#
# Epoch 50/200
# ----------
# gen_loss: 36.0574, gan_loss: 2.4774, l1_loss: 0.1679, disc_loss: 0.2500.
#
#
# Epoch 51/200
# ----------
# gen_loss: 35.9840, gan_loss: 2.5926, l1_loss: 0.1670, disc_loss: 0.2497.
#
#
# Epoch 52/200
# ----------
# gen_loss: 36.0636, gan_loss: 2.5952, l1_loss: 0.1673, disc_loss: 0.2396.
#
#
# Epoch 53/200
# ----------
# gen_loss: 35.7547, gan_loss: 2.5193, l1_loss: 0.1662, disc_loss: 0.2597.
#
#
# Epoch 54/200
# ----------
# gen_loss: 35.5391, gan_loss: 2.4685, l1_loss: 0.1654, disc_loss: 0.2520.
#
#
# Epoch 55/200
# ----------
# gen_loss: 35.7481, gan_loss: 2.5491, l1_loss: 0.1660, disc_loss: 0.2655.
#
#
# Epoch 56/200
# ----------
# gen_loss: 35.5650, gan_loss: 2.5645, l1_loss: 0.1650, disc_loss: 0.2461.
#
#
# Epoch 57/200
# ----------
# gen_loss: 36.1117, gan_loss: 2.6056, l1_loss: 0.1675, disc_loss: 0.2533.
#
#
# Epoch 58/200
# ----------
# gen_loss: 35.4528, gan_loss: 2.5114, l1_loss: 0.1647, disc_loss: 0.2366.
#
#
# Epoch 59/200
# ----------
# gen_loss: 35.4551, gan_loss: 2.5636, l1_loss: 0.1645, disc_loss: 0.2553.
#
#
# Epoch 60/200
# ----------
# gen_loss: 35.5957, gan_loss: 2.5313, l1_loss: 0.1653, disc_loss: 0.2511.
# saving model weights ...
#
#
# Epoch 61/200
# ----------
# gen_loss: 35.0740, gan_loss: 2.5434, l1_loss: 0.1627, disc_loss: 0.2485.
#
#
# Epoch 62/200
# ----------
# gen_loss: 35.2479, gan_loss: 2.6509, l1_loss: 0.1630, disc_loss: 0.2553.
#
#
# Epoch 63/200
# ----------
# gen_loss: 35.1463, gan_loss: 2.5677, l1_loss: 0.1629, disc_loss: 0.2385.
#
#
# Epoch 64/200
# ----------
# gen_loss: 35.5088, gan_loss: 2.6300, l1_loss: 0.1644, disc_loss: 0.2349.
#
#
# Epoch 65/200
# ----------
# gen_loss: 35.3565, gan_loss: 2.7289, l1_loss: 0.1631, disc_loss: 0.2397.
#
#
# Epoch 66/200
# ----------
# gen_loss: 34.9702, gan_loss: 2.6815, l1_loss: 0.1614, disc_loss: 0.2234.
#
#
# Epoch 67/200
# ----------
# gen_loss: 35.0073, gan_loss: 2.6569, l1_loss: 0.1618, disc_loss: 0.2524.
#
#
# Epoch 68/200
# ----------
# gen_loss: 34.6759, gan_loss: 2.7098, l1_loss: 0.1598, disc_loss: 0.2273.
#
#
# Epoch 69/200
# ----------
# gen_loss: 34.6719, gan_loss: 2.6228, l1_loss: 0.1602, disc_loss: 0.2562.
#
#
# Epoch 70/200
# ----------
# gen_loss: 34.9118, gan_loss: 2.7183, l1_loss: 0.1610, disc_loss: 0.2326.
#
#
# Epoch 71/200
# ----------
# gen_loss: 34.6265, gan_loss: 2.5924, l1_loss: 0.1602, disc_loss: 0.2417.
#
#
# Epoch 72/200
# ----------
# gen_loss: 34.5614, gan_loss: 2.6573, l1_loss: 0.1595, disc_loss: 0.2343.
#
#
# Epoch 73/200
# ----------
# gen_loss: 34.4017, gan_loss: 2.6153, l1_loss: 0.1589, disc_loss: 0.2394.
#
#
# Epoch 74/200
# ----------
# gen_loss: 34.3233, gan_loss: 2.7772, l1_loss: 0.1577, disc_loss: 0.2474.
#
#
# Epoch 75/200
# ----------
# gen_loss: 34.5500, gan_loss: 2.7780, l1_loss: 0.1589, disc_loss: 0.2387.
#
#
# Epoch 76/200
# ----------
# gen_loss: 34.4068, gan_loss: 2.6984, l1_loss: 0.1585, disc_loss: 0.2282.
#
#
# Epoch 77/200
# ----------
# gen_loss: 34.1751, gan_loss: 2.6520, l1_loss: 0.1576, disc_loss: 0.2557.
#
#
# Epoch 78/200
# ----------
# gen_loss: 34.0023, gan_loss: 2.6410, l1_loss: 0.1568, disc_loss: 0.2420.
#
#
# Epoch 79/200
# ----------
# gen_loss: 34.2394, gan_loss: 2.5834, l1_loss: 0.1583, disc_loss: 0.2464.
#
#
# Epoch 80/200
# ----------
# gen_loss: 34.2023, gan_loss: 2.5987, l1_loss: 0.1580, disc_loss: 0.2537.
# saving model weights ...
#
#
# Epoch 81/200
# ----------
# gen_loss: 33.8170, gan_loss: 2.6370, l1_loss: 0.1559, disc_loss: 0.2554.
#
#
# Epoch 82/200
# ----------
# gen_loss: 33.8585, gan_loss: 2.5140, l1_loss: 0.1567, disc_loss: 0.2654.
#
#
# Epoch 83/200
# ----------
# gen_loss: 33.7873, gan_loss: 2.5834, l1_loss: 0.1560, disc_loss: 0.2487.
#
#
# Epoch 84/200
# ----------
# gen_loss: 33.8933, gan_loss: 2.6272, l1_loss: 0.1563, disc_loss: 0.2563.
#
#
# Epoch 85/200
# ----------
# gen_loss: 33.7900, gan_loss: 2.6506, l1_loss: 0.1557, disc_loss: 0.2520.
#
#
# Epoch 86/200
# ----------
# gen_loss: 33.3477, gan_loss: 2.6208, l1_loss: 0.1536, disc_loss: 0.2405.
#
#
# Epoch 87/200
# ----------
# gen_loss: 33.5457, gan_loss: 2.6529, l1_loss: 0.1545, disc_loss: 0.2446.
#
#
# Epoch 88/200
# ----------
# gen_loss: 33.4662, gan_loss: 2.5980, l1_loss: 0.1543, disc_loss: 0.2815.
#
#
# Epoch 89/200
# ----------
# gen_loss: 33.3553, gan_loss: 2.5836, l1_loss: 0.1539, disc_loss: 0.2356.
#
#
# Epoch 90/200
# ----------
# gen_loss: 33.2662, gan_loss: 2.6289, l1_loss: 0.1532, disc_loss: 0.2449.
#
#
# Epoch 91/200
# ----------
# gen_loss: 33.4527, gan_loss: 2.5673, l1_loss: 0.1544, disc_loss: 0.2482.
#
#
# Epoch 92/200
# ----------
# gen_loss: 33.3987, gan_loss: 2.6343, l1_loss: 0.1538, disc_loss: 0.2441.
#
#
# Epoch 93/200
# ----------
# gen_loss: 33.3083, gan_loss: 2.6338, l1_loss: 0.1534, disc_loss: 0.2446.
#
#
# Epoch 94/200
# ----------
# gen_loss: 33.2799, gan_loss: 2.6243, l1_loss: 0.1533, disc_loss: 0.2470.
#
#
# Epoch 95/200
# ----------
# gen_loss: 33.6295, gan_loss: 2.6341, l1_loss: 0.1550, disc_loss: 0.2437.
#
#
# Epoch 96/200
# ----------
# gen_loss: 33.4147, gan_loss: 2.6448, l1_loss: 0.1538, disc_loss: 0.2604.
#
#
# Epoch 97/200
# ----------
# gen_loss: 33.1143, gan_loss: 2.6311, l1_loss: 0.1524, disc_loss: 0.2409.
#
#
# Epoch 98/200
# ----------
# gen_loss: 32.9660, gan_loss: 2.6420, l1_loss: 0.1516, disc_loss: 0.2435.
#
#
# Epoch 99/200
# ----------
# gen_loss: 33.1386, gan_loss: 2.7136, l1_loss: 0.1521, disc_loss: 0.2487.
#
#
# Epoch 100/200
# ----------
# gen_loss: 32.8953, gan_loss: 2.6792, l1_loss: 0.1511, disc_loss: 0.2410.
# saving model weights ...
#
#
# Epoch 101/200
# ----------
# gen_loss: 33.0991, gan_loss: 2.6052, l1_loss: 0.1525, disc_loss: 0.2433.
#
#
# Epoch 102/200
# ----------
# gen_loss: 33.1893, gan_loss: 2.6376, l1_loss: 0.1528, disc_loss: 0.2530.
#
#
# Epoch 103/200
# ----------
# gen_loss: 32.7381, gan_loss: 2.6302, l1_loss: 0.1505, disc_loss: 0.2515.
#
#
# Epoch 104/200
# ----------
# gen_loss: 32.9792, gan_loss: 2.6083, l1_loss: 0.1519, disc_loss: 0.2434.
#
#
# Epoch 105/200
# ----------
# gen_loss: 32.8031, gan_loss: 2.6888, l1_loss: 0.1506, disc_loss: 0.2258.
#
#
# Epoch 106/200
# ----------
# gen_loss: 33.1212, gan_loss: 2.6906, l1_loss: 0.1522, disc_loss: 0.2540.
#
#
# Epoch 107/200
# ----------
# gen_loss: 33.0220, gan_loss: 2.6384, l1_loss: 0.1519, disc_loss: 0.2539.
#
#
# Epoch 108/200
# ----------
# gen_loss: 32.8445, gan_loss: 2.6924, l1_loss: 0.1508, disc_loss: 0.2350.
#
#
# Epoch 109/200
# ----------
# gen_loss: 33.0518, gan_loss: 2.6793, l1_loss: 0.1519, disc_loss: 0.2573.
#
#
# Epoch 110/200
# ----------
# gen_loss: 32.6767, gan_loss: 2.6390, l1_loss: 0.1502, disc_loss: 0.2332.
#
#
# Epoch 111/200
# ----------
# gen_loss: 32.9234, gan_loss: 2.7187, l1_loss: 0.1510, disc_loss: 0.2283.
#
#
# Epoch 112/200
# ----------
# gen_loss: 32.8808, gan_loss: 2.6815, l1_loss: 0.1510, disc_loss: 0.2593.
#
#
# Epoch 113/200
# ----------
# gen_loss: 32.7858, gan_loss: 2.6727, l1_loss: 0.1506, disc_loss: 0.2411.
#
#
# Epoch 114/200
# ----------
# gen_loss: 32.6600, gan_loss: 2.7034, l1_loss: 0.1498, disc_loss: 0.2381.
#
#
# Epoch 115/200
# ----------
# gen_loss: 32.7541, gan_loss: 2.6799, l1_loss: 0.1504, disc_loss: 0.2297.
#
#
# Epoch 116/200
# ----------
# gen_loss: 32.5301, gan_loss: 2.7535, l1_loss: 0.1489, disc_loss: 0.2384.
#
#
# Epoch 117/200
# ----------
# gen_loss: 32.7191, gan_loss: 2.6775, l1_loss: 0.1502, disc_loss: 0.2404.
#
#
# Epoch 118/200
# ----------
# gen_loss: 32.6784, gan_loss: 2.7725, l1_loss: 0.1495, disc_loss: 0.2289.
#
#
# Epoch 119/200
# ----------
# gen_loss: 32.7125, gan_loss: 2.7541, l1_loss: 0.1498, disc_loss: 0.2451.
#
#
# Epoch 120/200
# ----------
# gen_loss: 32.5296, gan_loss: 2.7087, l1_loss: 0.1491, disc_loss: 0.2536.
# saving model weights ...
#
#
# Epoch 121/200
# ----------
# gen_loss: 32.5601, gan_loss: 2.6565, l1_loss: 0.1495, disc_loss: 0.2483.
#
#
# Epoch 122/200
# ----------
# gen_loss: 32.4065, gan_loss: 2.7766, l1_loss: 0.1481, disc_loss: 0.2328.
#
#
# Epoch 123/200
# ----------
# gen_loss: 32.5770, gan_loss: 2.6998, l1_loss: 0.1494, disc_loss: 0.2313.
#
#
# Epoch 124/200
# ----------
# gen_loss: 32.2822, gan_loss: 2.6813, l1_loss: 0.1480, disc_loss: 0.2397.
#
#
# Epoch 125/200
# ----------
# gen_loss: 32.2655, gan_loss: 2.7330, l1_loss: 0.1477, disc_loss: 0.2438.
#
#
# Epoch 126/200
# ----------
# gen_loss: 32.1965, gan_loss: 2.7038, l1_loss: 0.1475, disc_loss: 0.2488.
#
#
# Epoch 127/200
# ----------
# gen_loss: 32.1408, gan_loss: 2.7332, l1_loss: 0.1470, disc_loss: 0.2331.
#
#
# Epoch 128/200
# ----------
# gen_loss: 32.3887, gan_loss: 2.8039, l1_loss: 0.1479, disc_loss: 0.2412.
#
#
# Epoch 129/200
# ----------
# gen_loss: 32.3218, gan_loss: 2.7332, l1_loss: 0.1479, disc_loss: 0.2337.
#
#
# Epoch 130/200
# ----------
# gen_loss: 32.0973, gan_loss: 2.7661, l1_loss: 0.1467, disc_loss: 0.2373.
#
#
# Epoch 131/200
# ----------
# gen_loss: 32.0396, gan_loss: 2.7182, l1_loss: 0.1466, disc_loss: 0.2532.
#
#
# Epoch 132/200
# ----------
# gen_loss: 32.2386, gan_loss: 2.7079, l1_loss: 0.1477, disc_loss: 0.2367.
#
#
# Epoch 133/200
# ----------
# gen_loss: 32.2119, gan_loss: 2.7317, l1_loss: 0.1474, disc_loss: 0.2379.
#
#
# Epoch 134/200
# ----------
# gen_loss: 32.1953, gan_loss: 2.7034, l1_loss: 0.1475, disc_loss: 0.2287.
#
#
# Epoch 135/200
# ----------
# gen_loss: 32.2330, gan_loss: 2.6640, l1_loss: 0.1478, disc_loss: 0.2377.
#
#
# Epoch 136/200
# ----------
# gen_loss: 31.9074, gan_loss: 2.7437, l1_loss: 0.1458, disc_loss: 0.2485.
#
#
# Epoch 137/200
# ----------
# gen_loss: 32.2399, gan_loss: 2.7753, l1_loss: 0.1473, disc_loss: 0.2386.
#
#
# Epoch 138/200
# ----------
# gen_loss: 32.1235, gan_loss: 2.7512, l1_loss: 0.1469, disc_loss: 0.2454.
#
#
# Epoch 139/200
# ----------
# gen_loss: 32.2205, gan_loss: 2.6910, l1_loss: 0.1476, disc_loss: 0.2290.
#
#
# Epoch 140/200
# ----------
# gen_loss: 32.0925, gan_loss: 2.8259, l1_loss: 0.1463, disc_loss: 0.2319.
# saving model weights ...
#
#
# Epoch 141/200
# ----------
# gen_loss: 31.9010, gan_loss: 2.8214, l1_loss: 0.1454, disc_loss: 0.2490.
#
#
# Epoch 142/200
# ----------
# gen_loss: 32.1332, gan_loss: 2.7582, l1_loss: 0.1469, disc_loss: 0.2505.
#
#
# Epoch 143/200
# ----------
# gen_loss: 31.8545, gan_loss: 2.7808, l1_loss: 0.1454, disc_loss: 0.2408.
#
#
# Epoch 144/200
# ----------
# gen_loss: 31.8952, gan_loss: 2.8236, l1_loss: 0.1454, disc_loss: 0.2086.
#
#
# Epoch 145/200
# ----------
# gen_loss: 31.9099, gan_loss: 2.8216, l1_loss: 0.1454, disc_loss: 0.2541.
#
#
# Epoch 146/200
# ----------
# gen_loss: 32.0223, gan_loss: 2.7407, l1_loss: 0.1464, disc_loss: 0.2517.
#
#
# Epoch 147/200
# ----------
# gen_loss: 31.7436, gan_loss: 2.7806, l1_loss: 0.1448, disc_loss: 0.2552.
#
#
# Epoch 148/200
# ----------
# gen_loss: 31.9540, gan_loss: 2.8327, l1_loss: 0.1456, disc_loss: 0.2179.
#
#
# Epoch 149/200
# ----------
# gen_loss: 32.0237, gan_loss: 2.7949, l1_loss: 0.1461, disc_loss: 0.2434.
#
#
# Epoch 150/200
# ----------
# gen_loss: 31.8527, gan_loss: 2.8126, l1_loss: 0.1452, disc_loss: 0.2352.
#
#
# Epoch 151/200
# ----------
# gen_loss: 31.8386, gan_loss: 2.8053, l1_loss: 0.1452, disc_loss: 0.2308.
#
#
# Epoch 152/200
# ----------
# gen_loss: 31.7237, gan_loss: 2.7808, l1_loss: 0.1447, disc_loss: 0.2401.
#
#
# Epoch 153/200
# ----------
# gen_loss: 31.9142, gan_loss: 2.8115, l1_loss: 0.1455, disc_loss: 0.2264.
#
#
# Epoch 154/200
# ----------
# gen_loss: 31.6685, gan_loss: 2.7708, l1_loss: 0.1445, disc_loss: 0.2566.
#
#
# Epoch 155/200
# ----------
# gen_loss: 31.6512, gan_loss: 2.7768, l1_loss: 0.1444, disc_loss: 0.2361.
#
#
# Epoch 156/200
# ----------
# gen_loss: 31.7987, gan_loss: 2.7245, l1_loss: 0.1454, disc_loss: 0.2378.
#
#
# Epoch 157/200
# ----------
# gen_loss: 31.6436, gan_loss: 2.7481, l1_loss: 0.1445, disc_loss: 0.2426.
#
#
# Epoch 158/200
# ----------
# gen_loss: 31.7326, gan_loss: 2.7971, l1_loss: 0.1447, disc_loss: 0.2418.
#
#
# Epoch 159/200
# ----------
# gen_loss: 31.8465, gan_loss: 2.8113, l1_loss: 0.1452, disc_loss: 0.2513.
#
#
# Epoch 160/200
# ----------
# gen_loss: 31.6340, gan_loss: 2.8318, l1_loss: 0.1440, disc_loss: 0.2179.
# saving model weights ...
#
#
# Epoch 161/200
# ----------
# gen_loss: 31.5800, gan_loss: 2.8175, l1_loss: 0.1438, disc_loss: 0.2594.
#
#
# Epoch 162/200
# ----------
# gen_loss: 31.4943, gan_loss: 2.7175, l1_loss: 0.1439, disc_loss: 0.2410.
#
#
# Epoch 163/200
# ----------
# gen_loss: 31.6216, gan_loss: 2.7968, l1_loss: 0.1441, disc_loss: 0.2361.
#
#
# Epoch 164/200
# ----------
# gen_loss: 31.5437, gan_loss: 2.7002, l1_loss: 0.1442, disc_loss: 0.2393.
#
#
# Epoch 165/200
# ----------
# gen_loss: 31.6395, gan_loss: 2.8791, l1_loss: 0.1438, disc_loss: 0.2702.
#
#
# Epoch 166/200
# ----------
# gen_loss: 31.5651, gan_loss: 2.7824, l1_loss: 0.1439, disc_loss: 0.2231.
#
#
# Epoch 167/200
# ----------
# gen_loss: 31.6356, gan_loss: 2.7923, l1_loss: 0.1442, disc_loss: 0.2378.
#
#
# Epoch 168/200
# ----------
# gen_loss: 31.5031, gan_loss: 2.8296, l1_loss: 0.1434, disc_loss: 0.2309.
#
#
# Epoch 169/200
# ----------
# gen_loss: 31.3593, gan_loss: 2.8225, l1_loss: 0.1427, disc_loss: 0.2215.
#
#
# Epoch 170/200
# ----------
# gen_loss: 31.6256, gan_loss: 2.7760, l1_loss: 0.1442, disc_loss: 0.2394.
#
#
# Epoch 171/200
# ----------
# gen_loss: 31.4032, gan_loss: 2.8411, l1_loss: 0.1428, disc_loss: 0.2163.
#
#
# Epoch 172/200
# ----------
# gen_loss: 31.7054, gan_loss: 2.8428, l1_loss: 0.1443, disc_loss: 0.2705.
#
#
# Epoch 173/200
# ----------
# gen_loss: 31.6458, gan_loss: 2.8710, l1_loss: 0.1439, disc_loss: 0.2372.
#
#
# Epoch 174/200
# ----------
# gen_loss: 31.5269, gan_loss: 2.7111, l1_loss: 0.1441, disc_loss: 0.2409.
#
#
# Epoch 175/200
# ----------
# gen_loss: 31.3919, gan_loss: 2.8356, l1_loss: 0.1428, disc_loss: 0.2302.
#
#
# Epoch 176/200
# ----------
# gen_loss: 31.5870, gan_loss: 2.8208, l1_loss: 0.1438, disc_loss: 0.2298.
#
#
# Epoch 177/200
# ----------
# gen_loss: 31.4979, gan_loss: 2.8657, l1_loss: 0.1432, disc_loss: 0.2422.
#
#
# Epoch 178/200
# ----------
# gen_loss: 31.6552, gan_loss: 2.9225, l1_loss: 0.1437, disc_loss: 0.2433.
#
#
# Epoch 179/200
# ----------
# gen_loss: 31.5282, gan_loss: 2.7523, l1_loss: 0.1439, disc_loss: 0.2482.
#
#
# Epoch 180/200
# ----------
# gen_loss: 31.5617, gan_loss: 2.8172, l1_loss: 0.1437, disc_loss: 0.2337.
# saving model weights ...
#
#
# Epoch 181/200
# ----------
# gen_loss: 31.4911, gan_loss: 2.7384, l1_loss: 0.1438, disc_loss: 0.2463.
#
#
# Epoch 182/200
# ----------
# gen_loss: 31.3431, gan_loss: 2.7580, l1_loss: 0.1429, disc_loss: 0.2330.
#
#
# Epoch 183/200
# ----------
# gen_loss: 31.2401, gan_loss: 2.8481, l1_loss: 0.1420, disc_loss: 0.2493.
#
#
# Epoch 184/200
# ----------
# gen_loss: 31.3331, gan_loss: 2.8659, l1_loss: 0.1423, disc_loss: 0.2327.
#
#
# Epoch 185/200
# ----------
# gen_loss: 31.4559, gan_loss: 2.8581, l1_loss: 0.1430, disc_loss: 0.2339.
#
#
# Epoch 186/200
# ----------
# gen_loss: 31.3811, gan_loss: 2.8509, l1_loss: 0.1427, disc_loss: 0.2433.
#
#
# Epoch 187/200
# ----------
# gen_loss: 31.5568, gan_loss: 2.8543, l1_loss: 0.1435, disc_loss: 0.2321.
#
#
# Epoch 188/200
# ----------
# gen_loss: 31.3821, gan_loss: 2.8269, l1_loss: 0.1428, disc_loss: 0.2235.
#
#
# Epoch 189/200
# ----------
# gen_loss: 31.3735, gan_loss: 2.8370, l1_loss: 0.1427, disc_loss: 0.2395.
#
#
# Epoch 190/200
# ----------
# gen_loss: 31.1298, gan_loss: 2.9078, l1_loss: 0.1411, disc_loss: 0.2216.
#
#
# Epoch 191/200
# ----------
# gen_loss: 31.2947, gan_loss: 2.8663, l1_loss: 0.1421, disc_loss: 0.2506.
#
#
# Epoch 192/200
# ----------
# gen_loss: 31.2746, gan_loss: 2.8470, l1_loss: 0.1421, disc_loss: 0.2422.
#
#
# Epoch 193/200
# ----------
# gen_loss: 30.9460, gan_loss: 2.7985, l1_loss: 0.1407, disc_loss: 0.2208.
#
#
# Epoch 194/200
# ----------
# gen_loss: 31.1947, gan_loss: 2.8240, l1_loss: 0.1419, disc_loss: 0.2598.
#
#
# Epoch 195/200
# ----------
# gen_loss: 31.3721, gan_loss: 2.8808, l1_loss: 0.1425, disc_loss: 0.2453.
#
#
# Epoch 196/200
# ----------
# gen_loss: 31.1434, gan_loss: 2.8351, l1_loss: 0.1415, disc_loss: 0.2243.
#
#
# Epoch 197/200
# ----------
# gen_loss: 31.2613, gan_loss: 2.8189, l1_loss: 0.1422, disc_loss: 0.2347.
#
#
# Epoch 198/200
# ----------
# gen_loss: 31.2203, gan_loss: 2.8465, l1_loss: 0.1419, disc_loss: 0.2357.
#
#
# Epoch 199/200
# ----------
# gen_loss: 31.3386, gan_loss: 2.8482, l1_loss: 0.1425, disc_loss: 0.2386.
#
#
# Epoch 200/200
# ----------
# gen_loss: 31.3289, gan_loss: 2.8946, l1_loss: 0.1422, disc_loss: 0.2557.
# saving model weights ...
#
#
# Training complete in 43m 6s
