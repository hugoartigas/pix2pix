# %% [markdown]
# # Training notebook

# %% [markdown]
# The goal of this notebook is to obtain pictures generated by the Pix2Pix model at different stages of training.

# %% [markdown]
# ### 0. Libraries and dataset

# %%
import utils
import model

# %%
# set dataset name
dataset_name = 'maps'

# %% [markdown]
# ## I. No transformation, batch size of 1

# %% [markdown]
# ### 1. Instantiate dataloaders

# %%
# instantiate datasets and dataloaders
datasets = {mode: utils.ImageDataset(dataset_name = dataset_name, transform=utils.data_transforms[mode], mode = mode) for mode in ['train', 'val']}
dataloaders = {'train': utils.DataLoader(datasets['train'], batch_size=1, shuffle=True),
                    'val': utils.DataLoader(datasets['val'], batch_size=1, shuffle=False)}

# %% [markdown]
# ### 2. Create model

# %%
# instantiate model
p2p = model.Pix2Pix().to(utils.device)

# %% [markdown]
# ### 3. Train

# %%
history = utils.train(model = p2p,
            n_epochs = 200,
            display_step = 20,
            save_step = 20,
            dataloaders = dataloaders,
            filename = 'maps_long_da',
            lr = 2e-4,
            lbd = 200,
            loss_l1_true = True,
            loss_l2_true = False,
            loss_cGAN_true = True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_17124/1104955758.py in <module>
#       9             loss_l1_true = True,
#      10             loss_l2_true = False,
# ---> 11             loss_cGAN_true = True)
#
# ~/e6691-2022spring-project-abvz-ha2605-av3023-wb2138/utils.py in train(model, n_epochs, display_step, save_step, dataloaders, filename, lr, lbd, loss_l1_true, loss_l2_true, loss_cGAN_true)
#     203     with torch.no_grad():
#     204         input_val, real_val = next(iter(dataloaders['val']))
# --> 205         generate_images(model = model, input = input_val, real = real_val)
#     206     # switch back to train mode
#     207     model.train()
#
# ~/e6691-2022spring-project-abvz-ha2605-av3023-wb2138/utils.py in generate_images(model, input, real)
#     120     model       : Pix2Pix model
#     121     """
# --> 122     prediction = model.generator(input.to(device))
#     123
#     124     # create figure
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/e6691-2022spring-project-abvz-ha2605-av3023-wb2138/model.py in forward(self, x)
#      86         for up, skip in zip(self.upsample_layers, skips):
#      87             x = up(x)
# ---> 88             x = torch.cat((x, skip), 1)
#      89
#      90         # apply last layer
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 8 but got size 9 for tensor number 1 in the list.
